# %% [markdown]
# # DB 연결 및 데이터 테스트
#
# 이 노트북은 Flask 애플리케이션의 데이터베이스에 연결하고 `RealEstateTransaction` 및 `PublicParking` 모델에서 데이터를 가져옵니다.

# %%
from utils import setup_db_context
import pandas as pd
import numpy as np
from sqlalchemy import select

# DB 컨텍스트 설정
app, db = setup_db_context()

from myapp.models import RealEstateTransaction, PublicParking
# Out:
# 데이터베이스 연결 및 앱 컨텍스트 푸시 완료.

# %% [markdown]
# ## 1. 부동산 실거래가 (Real Estate Transactions)

# %%
# SQLAlchemy를 사용하여 데이터 가져오기
transactions = RealEstateTransaction.query.limit(5).all()
print(f"가져온 거래 수: {len(transactions)}")

# DataFrame으로 변환
stmt = select(RealEstateTransaction)
df_ret = pd.read_sql(stmt, db.session.connection())

print(f"총 레코드 수: {len(df_ret)}")
df_ret.head()
# Out:
# 가져온 거래 수: 5
# 총 레코드 수: 235671
#    ret_id  reception_year district_code district_name legal_dong_code  \
# 0       2            2025         11320           도봉구           10600
# 1       3            2025         11380           은평구           10800
# 2       4            2025         11500           강서구           10200
# 3       5            2025         11620           관악구           10200
# 4       6            2025         11530           구로구           10600
#
#   legal_dong_name jibun_type jibun_type_name main_number sub_number  ...  \
# 0             방학동          1              대지        0638       0010  ...
# 1             역촌동                                                    ...
# 2             등촌동          1              대지        0628       0013  ...
# 3             신림동          1              대지        1639       0051  ...
# 4             고척동          1              대지        0339       0000  ...
#
#   amount building_area  land_area  floor right_type cancel_date  \
# 0  14800         37.66       16.0      4
# 1  39620         74.08      182.0
# 2  10300         26.16      35.71      6
# 3  12700         18.70      26.16      8
# 4  84000         59.89        0.0      9
#
#   construction_year building_use  declaration_type broker_district_name
# 0            1994.0        연립다세대              중개거래               서울 도봉구
# 1            1972.0        단독다가구               직거래
# 2            1999.0         오피스텔              중개거래               서울 강서구
# 3            2014.0         오피스텔              중개거래               서울 관악구
# 4            2009.0          아파트              중개거래       서울 구로구, 서울 양천구
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 2. 공영주차장 (Public Parkings)

# %%
# SQLAlchemy를 사용하여 데이터 가져오기
parkings = PublicParking.query.limit(5).all()
print(f"가져온 주차장 레코드 수: {len(parkings)}")

# DataFrame으로 변환
stmt = select(PublicParking)
df_pp = pd.read_sql(stmt, db.session.connection())

print(f"총 레코드 수: {len(df_pp)}")
df_pp.head()
# Out:
# 가져온 주차장 레코드 수: 5
# 총 레코드 수: 1875
#    pp_id parking_code     parking_name         address parking_type  \
# 0      1       171721     세종로 공영주차장(시)    종로구 세종로 80-1           NW
# 1      2       171730   종묘주차장 공영주차장(시)     종로구 훈정동 2-0           NW
# 2      3       171900   훈련원공원 공영주차장(시)   중구 을지로5가 40-3           NW
# 3      4       172051    한강진역 공영주차장(시)  용산구 한남동 728-27           NW
# 4      5       172065  용산주차빌딩 공영주차장(시)  용산구 한강로2가 12-9           NW
#
#   parking_type_name operation_type operation_type_name  phone_number  \
# 0            노외 주차장              1             시간제 주차장  02-2290-6566
# 1            노외 주차장              1             시간제 주차장  02-2290-6166
# 2            노외 주차장              1             시간제 주차장  02-3405-4597
# 3            노외 주차장              1             시간제 주차장   02-795-6406
# 4            노외 주차장              1             시간제 주차장  02-2290-6014
#
#   parking_status_available  ... bus_basic_time_min  bus_add_rate  \
# 0                        1  ...                  0             0
# 1                        1  ...                  0             0
# 2                        1  ...                  0             0
# 3                        1  ...                  0             0
# 4                        1  ...                  0             0
#
#    bus_add_time_min day_max_rate        lat         lng  \
# 0                 0        30900  37.573403  126.975884
# 1                 0        28800  37.571504  126.994969
# 2                 0        39600  37.567400  127.003521
# 3                 0        28800  37.539522  127.002580
# 4                 0        21600  37.534364  126.965418
#
#   share_parking_company_name share_parking share_parking_company_link  \
# 0                                        N
# 1                                        N
# 2                                        N
# 3                                        N
# 4                                        N
#
#   share_parking_etc
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 45 columns]

# %%
df_ret.value_counts()
# Out:
# ret_id  reception_year  district_code  district_name  legal_dong_code  legal_dong_name  jibun_type  jibun_type_name  main_number  sub_number  building_name  contract_date  amount  building_area  land_area  floor  right_type  cancel_date  construction_year  building_use  declaration_type  broker_district_name
# 2       2025            11320          도봉구            10600            방학동              1           대지               0638         0010        한신빌라(638-10)   20250117       14800   37.66          16.0       4                               1994.0             연립다세대         중개거래              서울 도봉구                  1
# 156984  2023            11200          성동구            10400            도선동              1           대지               0022         0001        다남매타워          20230313       27000   43.05          60.88      9                               2009.0             오피스텔          중개거래              서울 성동구                  1
# 156986  2023            11170          용산구            10900            청파동1가            1           대지               0084         0003        목화             20230313       40000   57.50          0.0        6                               2004.0             아파트           중개거래              서울 용산구                  1
# 156987  2023            11350          노원구            10300            공릉동              1           대지               0081         0000        태강아파트(아이파크)    20230313       41000   49.60          0.0        4                               1999.0             아파트           직거래                                       1
# 156988  2023            11440          마포구            12200            합정동              1           대지               0458         0009        미도빌라           20230313       44500   37.21          36.5       2                               1990.0             연립다세대         중개거래              서울 마포구                  1
#                                                                                                                                                                                                                                                                                                                         ..
# 78489   2024            11380          은평구            10300            불광동              1           대지               0170         0034        수안채            20240402       35000   44.59          33.0       5                               2017.0             연립다세대         중개거래              서울 은평구                  1
# 78490   2024            11560          영등포구           13200            신길동              1           대지               4964         0000        신길센트럴자이아파트     20240402       128000  84.98                     12                              2021.0             아파트           중개거래              서울 영등포구                 1
# 78491   2024            11260          중랑구            10400            묵동               1           대지               0167         0000        신도             20240402       69500   84.89                     17                 20240402     1998.0             아파트           중개거래              서울 중랑구                  1
# 78492   2024            11320          도봉구            10600            방학동              1           대지               0271         0001        신동아아파트1        20240402       37500   53.16                     12                              1986.0             아파트           중개거래              서울 도봉구                  1
# 235671  2022            11290          성북구            13300            정릉동              1           대지               0260         0010        진안빌라A(260-10)  20160426       35000   57.95          42.4       2                               1991.0             연립다세대                                                   1
# Name: count, Length: 234434, dtype: int64

# %%
df_pp.value_counts()
# Out:
# pp_id  parking_code  parking_name      address        parking_type  parking_type_name  operation_type  operation_type_name  phone_number  parking_status_available  parking_status_available_name  total_spaces  current_parking  current_parking_update_time  pay_type  pay_type_name  night_free_open  night_free_open_name  weekday_start_time  weekday_end_time  weekend_start_time  weekend_end_time  holiday_start_time  holiday_end_time  saturday_pay_type  saturday_pay_type_name  holiday_pay_type  holiday_pay_type_name  monthly_rate  street_parking_group_no  basic_rate  basic_time_min  add_rate  add_time_min  bus_basic_rate  bus_basic_time_min  bus_add_rate  bus_add_time_min  day_max_rate  lat        lng         share_parking_company_name  share_parking  share_parking_company_link  share_parking_etc
# 1      171721        세종로 공영주차장(시)      종로구 세종로 80-1   NW            노외 주차장             1               시간제 주차장              02-2290-6566  1                         현재~20분이내 연계데이터 존재(현재 주차대수 표현)  1260          655              2025.1.21 11:11              Y         유료             N                야간 미개방                0000                2400              0000                2400              0000                2400              N                  무료                      N                 무료                     176000                                 430         5               430       5             0               0                   0             0                 30900         37.573403  126.975884                              N                                                               1
# 1246   1561603       여의서로 공영주차장(시)     영등포구 여의도동 8-1  NS            노상 주차장             1               시간제 주차장                            1                         현재~20분이내 연계데이터 존재(현재 주차대수 표현)  1             38               2025.1.21 11:11              Y         유료             N                야간 미개방                0900                1900              0900                1500              0000                0000              N                  무료                      Y                 유료                                   1.15601E+12              160         5               160       5             0               0                   0             0                               37.530102  126.912269                              N                                                               1
# 1258   1561603       여의서로 공영주차장(시)     영등포구 여의도동 8-1  NS            노상 주차장             1               시간제 주차장                            1                         현재~20분이내 연계데이터 존재(현재 주차대수 표현)  1             38               2025.1.21 11:11              Y         유료             N                야간 미개방                0900                1900              0900                1500              0000                0000              N                  무료                      Y                 유료                                   1.15601E+12              160         5               160       5             0               0                   0             0                               37.533110  126.917356                              N                                                               1
# 1257   1561603       여의서로 공영주차장(시)     영등포구 여의도동 8-1  NS            노상 주차장             1               시간제 주차장                            1                         현재~20분이내 연계데이터 존재(현재 주차대수 표현)  1             38               2025.1.21 11:11              Y         유료             N                야간 미개방                0900                1900              0900                1500              0000                0000              N                  무료                      Y                 유료                                   1.15601E+12              160         5               160       5             0               0                   0             0                               37.533296  126.916323                              N                                                               1
# 1256   1561603       여의서로 공영주차장(시)     영등포구 여의도동 8-1  NS            노상 주차장             1               시간제 주차장                            1                         현재~20분이내 연계데이터 존재(현재 주차대수 표현)  1             38               2025.1.21 11:11              Y         유료             N                야간 미개방                0900                1900              0900                1500              0000                0000              N                  무료                      Y                 유료                                   1.15601E+12              160         5               160       5             0               0                   0             0                               37.533344  126.915923                              N                                                               1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ..
# 621    1452721       청계2(북1) 공영주차장(시)  종로구 관수동 91-4   NS            노상 주차장             1               시간제 주차장                            1                         현재~20분이내 연계데이터 존재(현재 주차대수 표현)  1             7                2025.1.21 11:11              Y         유료             N                야간 미개방                0900                1900              0900                1500              0000                0000              N                  무료                      Y                 유료                     0             1.11102E+12              750         5               750       5             0               0                   0             0                 0             37.568597  126.993222                              N                                                               1
# 620    1452721       청계2(북1) 공영주차장(시)  종로구 관수동 91-4   NS            노상 주차장             1               시간제 주차장                            1                         현재~20분이내 연계데이터 존재(현재 주차대수 표현)  1             7                2025.1.21 11:11              Y         유료             N                야간 미개방                0900                1900              0900                1500              0000                0000              N                  무료                      Y                 유료                     0             1.11102E+12              750         5               750       5             0               0                   0             0                 0             37.568601  126.993288                              N                                                               1
# 619    1452721       청계2(북1) 공영주차장(시)  종로구 관수동 91-4   NS            노상 주차장             1               시간제 주차장                            1                         현재~20분이내 연계데이터 존재(현재 주차대수 표현)  1             7                2025.1.21 11:11              Y         유료             N                야간 미개방                0900                1900              0900                1500              0000                0000              N                  무료                      Y                 유료                     0             1.11102E+12              750         5               750       5             0               0                   0             0                 0             37.568640  126.993893                              N                                                               1
# 618    1452721       청계2(북1) 공영주차장(시)  종로구 관수동 91-4   NS            노상 주차장             1               시간제 주차장                            1                         현재~20분이내 연계데이터 존재(현재 주차대수 표현)  1             7                2025.1.21 11:11              Y         유료             N                야간 미개방                0900                1900              0900                1500              0000                0000              N                  무료                      Y                 유료                     0             1.11102E+12              750         5               750       5             0               0                   0             0                 0             37.568589  126.993088                              N                                                               1
# 1874   3246676       서울암사동유적 주차장(시)    강동구 암사동 139-2  NW            노외 주차장             1               시간제 주차장                            0                         미연계중                           108           0                                             Y         유료             N                야간 미개방                0900                1800              0900                1800              0900                1800              N                  무료                      N                 무료                                                            1000        540             1000      540           0               0                   0             0                               37.559172  127.130342                              N                                                               1
# Name: count, Length: 1874, dtype: int64

# %%
df_ret_grouped = df_ret.groupby(['district_name', 'reception_year'])
df_ret_grouped

# %%
df_ret_grouped

# %% [markdown]
# ### 호갱노노 동별 매물 리스트

# %%
import requests

dong_code = "1132010700"
header = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}
res = requests.get(f"https://hogangnono.com/api/region/{dong_code}/apt?areaRoughly=0", headers=header)
json_obj = res.json()
print(json_obj)
json_obj['data']['apts'][0]
# Out:
# {'status': 'success', 'data': {'id': '1132010700', 'name': '서울특별시 도봉구 창동', 'sido': '11', 'sido_name': '서울특별시', 'sigungu': '320', 'sigungu_name': '도봉구', 'dong': '107', 'dong_name': '창동', 'ri': '00', 'ri_name': '', 'date': '2021-08-12T14:22:10.000Z', 'is_expired': 0, 'close_region': '["1130510200","1132010500","1135010200","1132010600","1130510300","1135010500","1132010500","1132010600","1132010700","1132010800"]', 'is_customized': 1, 'lat': 37.6483046, 'lng': 127.0438683, 'regionCode': '1132010700', 'areaRoughly': 0, 'apts': [{'id': 'aXeb6', 'type': 0, 'sub_type': 1, 'admin_region_code': '1132051200', 'region_code': '1132010700', 'name': 'DK포시즌', 'address': '서울특별시 도봉구 창동 442-33', 'road_address': '서울특별시 도봉구 덕릉로 283', 'alias_name': None, 'portal_id': 113414, 'trade_count': 17, 'trade_recent_count': 0, 'popularity': 0, 'trade_rate': 5, 'deposit_rate': 0, 'rent_rate': 0, 'offer_date': None, 'total_household': 19, 'average_rating': 0, 'baseinfo': {'company': '디케이종합건설(주)', 'heat_type': '개별난방', 'asile_type': '계단식', 'heat_source': '도시가스', 'parking_rate': 38.6, 'permission_date': '20020820'}, 'aisle_type': 1, 'heat_type': 3, 'photos': None, 'nearby_school_point': 1, 'nearby_subway_station_count': 0, 'floor_area_ratio': None, 'building_coverage_ratio': None, 'rental_business_ratio': 0, 'total_rental_business_household': 0, 'business_call_price': 62, '도로명주소_관리번호': '', '도로명주소_코드': '', 'pnu': '', 'created_date': '2023-09-04T14:14:01.000Z', 'last_modified_at': '2024-06-30T21:19:50.000Z', 'area': {'id': 120033, 'no': 3, 'merged_no': 3, 'private_area': 83.7, 'public_area': 102.15, 'molit_type': None, 'real_trade_price': 0, 'real_rent_price': 0, 'real_rent_ratio': 0, 'portal_trade_price': 0, 'portal_rent_price': 0, 'portal_rent_ratio': 0, 'offer_price': 0, 'offer_result': None, 'offer_non_ranking_result': None, 'loanable_trade_price': 10000, 'loanable_rent_price': 16000, 'second_max_real_trade_price': 22000, 'second_max_real_rent_price': 20000, 'max_real_trade_price': 25000, 'max_real_rent_price': 21250, 'max_real_trade_data': '{"price":25000,"floor":6}', 'max_real_rent_data': '{"price":21250,"floor":5}', 'date_offer_price': None, 'date_loan': None, 'date_official_price': '2024-12-31T15:00:00.000Z', 'date_second_max_real_trade': '2015-07-07T15:00:00.000Z', 'date_second_max_real_rent': '2019-06-16T15:00:00.000Z', 'date_max_real_trade': '2020-01-06T15:00:00.000Z', 'date_max_real_rent': '2021-05-10T15:00:00.000Z', 'is_major': 1, 'total_household': 6, 'photos': None, 'popular_type': {'building': [{'name': '1', 'price': 0}], 'area': [{'areaId': 120033, 'type': '102A', 'price': 0}]}, 'trade_recent_count': 0, 'type_real_trade_price': 0, 'type_real_rent_price': 0, 'type_portal_trade_price': 0, 'type_portal_rent_price': 0, 'type_official_price': 21200, 'reg_mapping_rate': 0, 'is_expired': 0, 'merged_into': None, 'profit_ratio': 0, 'type_official_price_data': {'2005-12-31 15:00:00': 12000, '2006-12-31 15:00:00': 12000, '2007-12-31 15:00:00': 14400, '2008-12-31 15:00:00': 15100, '2009-12-31 15:00:00': 14600, '2010-12-31 15:00:00': 14400, '2011-12-31 15:00:00': 14600, '2012-12-31 15:00:00': 14600, '2013-12-31 15:00:00': 14600, '2014-12-31 15:00:00': 15300, '2015-12-31 15:00:00': 16700, '2016-12-31 15:00:00': 16800, '2017-12-31 15:00:00': 17600, '2018-12-31 15:00:00': 17800, '2019-12-31 15:00:00': 17800, '2020-12-31 15:00:00': 19300, '2021-12-31 15:00:00': 21400, '2022-12-31 15:00:00': 18800, '2023-12-31 15:00:00': 18800, '2024-12-31 15:00:00': 21200}, 'type_real_price_per_official_price_data': {'2024-12-31 15:00:00': 0.848, '2023-12-31 15:00:00': 0.752, '2022-12-31 15:00:00': 0.752, '2021-12-31 15:00:00': 0.856, '2020-12-31 15:00:00': 0.772, '2019-12-31 15:00:00': 0.712, '2018-12-31 15:00:00': 0.809, '2017-12-31 15:00:00': 0.8, '2016-12-31 15:00:00': 0.764, '2015-12-31 15:00:00': 0.759}, 'type_official_price_increase_ratio': 0.057, 'type_real_price_increase_ratio': 0, 'manual_map': None, 'offer_household': 0, 'member_household': 0, 'etc_household': 0, 'ren ...
# {'id': 'aXeb6',
#  'type': 0,
#  'sub_type': 1,
#  'admin_region_code': '1132051200',
#  'region_code': '1132010700',
#  'name': 'DK포시즌',
#  'address': '서울특별시 도봉구 창동 442-33',
#  'road_address': '서울특별시 도봉구 덕릉로 283',
#  'alias_name': None,
#  'portal_id': 113414,
#  'trade_count': 17,
#  'trade_recent_count': 0,
#  'popularity': 0,
#  'trade_rate': 5,
#  'deposit_rate': 0,
#  'rent_rate': 0,
#  'offer_date': None,
#  'total_household': 19,
#  'average_rating': 0,
#  'baseinfo': {'company': '디케이종합건설(주)',
#   'heat_type': '개별난방',
#   'asile_type': '계단식',
#   'heat_source': '도시가스',
#   'parking_rate': 38.6,
#   'permission_date': '20020820'},
#  'aisle_type': 1,
#  'heat_type': 3,
#  'photos': None,
#  'nearby_school_point': 1,
#  'nearby_subway_station_count': 0,
#  'floor_area_ratio': None,
#  'building_coverage_ratio': None,
#  'rental_business_ratio': 0,
#  'total_rental_business_household': 0,
#  'business_call_price': 62,
#  '도로명주소_관리번호': '',
#  '도로명주소_코드': '',
#  'pnu': '',
#  'created_date': '2023-09-04T14:14:01.000Z',
#  'last_modified_at': '2024-06-30T21:19:50.000Z',
#  'area': {'id': 120033,
#   'no': 3,
#   'merged_no': 3,
#   'private_area': 83.7,
#   'public_area': 102.15,
#   'molit_type': None,
#   'real_trade_price': 0,
#   'real_rent_price': 0,
#   'real_rent_ratio': 0,
#   'portal_trade_price': 0,
#   'portal_rent_price': 0,
#   'portal_rent_ratio': 0,
#   'offer_price': 0,
#   'offer_result': None,
#   'offer_non_ranking_result': None,
#   'loanable_trade_price': 10000,
#   'loanable_rent_price': 16000,
#   'second_max_real_trade_price': 22000,
#   'second_max_real_rent_price': 20000,
#   'max_real_trade_price': 25000,
#   'max_real_rent_price': 21250,
#   'max_real_trade_data': '{"price":25000,"floor":6}',
#   'max_real_rent_data': '{"price":21250,"floor":5}',
#   'date_offer_price': None,
#   'date_loan': None,
#   'date_official_price': '2024-12-31T15:00:00.000Z',
#   'date_second_max_real_trade': '2015-07-07T15:00:00.000Z',
#   'date_second_max_real_rent': '2019-06-16T15:00:00.000Z',
#   'date_max_real_trade': '2020-01-06T15:00:00.000Z',
#   'date_max_real_rent': '2021-05-10T15:00:00.000Z',
#   'is_major': 1,
#   'total_household': 6,
#   'photos': None,
#   'popular_type': {'building': [{'name': '1', 'price': 0}],
#    'area': [{'areaId': 120033, 'type': '102A', 'price': 0}]},
#   'trade_recent_count': 0,
#   'type_real_trade_price': 0,
#   'type_real_rent_price': 0,
#   'type_portal_trade_price': 0,
#   'type_portal_rent_price': 0,
#   'type_official_price': 21200,
#   'reg_mapping_rate': 0,
#   'is_expired': 0,
#   'merged_into': None,
#   'profit_ratio': 0,
#   'type_official_price_data': {'2005-12-31 15:00:00': 12000,
#    '2006-12-31 15:00:00': 12000,
#    '2007-12-31 15:00:00': 14400,
#    '2008-12-31 15:00:00': 15100,
#    '2009-12-31 15:00:00': 14600,
#    '2010-12-31 15:00:00': 14400,
#    '2011-12-31 15:00:00': 14600,
#    '2012-12-31 15:00:00': 14600,
#    '2013-12-31 15:00:00': 14600,
#    '2014-12-31 15:00:00': 15300,
#    '2015-12-31 15:00:00': 16700,
#    '2016-12-31 15:00:00': 16800,
#    '2017-12-31 15:00:00': 17600,
#    '2018-12-31 15:00:00': 17800,
#    '2019-12-31 15:00:00': 17800,
#    '2020-12-31 15:00:00': 19300,
#    '2021-12-31 15:00:00': 21400,
#    '2022-12-31 15:00:00': 18800,
#    '2023-12-31 15:00:00': 18800,
#    '2024-12-31 15:00:00': 21200},
#   'type_real_price_per_official_price_data': {'2024-12-31 15:00:00': 0.848,
#    '2023-12-31 15:00:00': 0.752,
#    '2022-12-31 15:00:00': 0.752,
#    '2021-12-31 15:00:00': 0.856,
#    '2020-12-31 15:00:00': 0.772,
#    '2019-12-31 15:00:00': 0.712,
#    '2018-12-31 15:00:00': 0.809,
#    '2017-12-31 15:00:00': 0.8,
#    '2016-12-31 15:00:00': 0.764,
#    '2015-12-31 15:00:00': 0.759},
#   'type_official_price_increase_ratio': 0.057,
#   'type_real_price_increase_ratio': 0,
#   'manual_map': None,
#   'offer_household': 0,
#   'member_household': 0,
#   'etc_household': 0,
#   'rent_household': 0,
#   'pyTotalHousehold': 7,
#   'area_type': '102A'},
#  'start_month': '2003-05-21T15:00:00.000Z',
#  'lat': 37.642409,
#  'lng': 127.041285,
#  'diffYearText': '2003년 5월(23년차)',
#  'diffYearShortText': '입주 23년차',
#  'dong': '창동',
#  'isOffer': False,
#  'status': 5}
