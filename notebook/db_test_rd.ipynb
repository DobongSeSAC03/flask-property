# %% [markdown]
# # DB 연결 및 데이터 테스트
#
# 이 노트북은 Flask 애플리케이션의 데이터베이스에 연결하고 `RealEstateTransaction` 및 `PublicParking` 모델에서 데이터를 가져옵니다.

# %%
from utils import setup_db_context
import pandas as pd
from sqlalchemy import select

# DB 컨텍스트 설정
app, db = setup_db_context()

from myapp.models import RealEstateTransaction, PublicParking
# Out:
# 데이터베이스 연결 및 앱 컨텍스트 푸시 완료.

# %% [markdown]
# ## 1. 부동산 실거래가 (Real Estate Transactions)

# %%
# input data 예시 "지역구" = 도봉구, "법정동" = 방학동 | "법정동" 데이터는 프론트로 부터 받지 않을 수도 있음.
input_district_name = "강남구"
input_legal_dong_name = None

# SQLAlchemy를 사용하여 데이터 가져오기
transactions = RealEstateTransaction.query.limit(5).all()
# print(f"가져온 거래 수: {len(transactions)}")

# DataFrame으로 변환
stmt = select(RealEstateTransaction)
df_ret = pd.read_sql(stmt, db.session.connection())


# 지역구 필터링
def filter_by_district(df, district_name):
    return df[df['district_name'] == district_name].copy()


# 전체 구 | 평단가 계산 | 건물 가격 단위(만원) | 건물 면적 단위 (m^2) | 모든 건물의 평균 단가 개발 계산 | price_per_sqm 컬럼 생성
def calc_price_per_sqm(df):
    df = df.copy()
    df['price_per_sqm'] = (
        df['amount'] * 10000
    ) / df['building_area']
    return df


# 법정동 연도별 평단가 평균 계산 | yearly_avg_price DataFrame 생성 | transaction_count, avg_price_per_sqm 컬럼 생성
def calc_yearly_avg_price(df):
    df = df.copy()
    return (
        df
        .groupby(['reception_year', 'district_name', 'legal_dong_name'])
        .agg(
            avg_price_per_sqm=('price_per_sqm', 'mean'),
            transaction_count=('price_per_sqm', 'count')
        )
        .reset_index()
        .sort_values(['legal_dong_name', 'district_name', 'reception_year'])
    )


# 포맷팅 round(0)으로 소수점 첫 째 자리에서 반올림 | price_per_sqm_format 컬럼 생성
def format_price_column(df):
    df = df.copy()
    df['price_per_sqm_format'] = (
        df['avg_price_per_sqm']
        .round(0)
        .map(lambda x: f"{int(x):,}")
    )
    return df

# 연도별 상승률 | yoy_change_rate 컬럼생성 | 앞 행(전년도)과의 평단가의 차이 %로 계산
def calc_yoy_change_rate(df):
    df = df.copy()
    df['yoy_change_rate'] = (
        df
        .groupby(['district_name', 'legal_dong_name'])['avg_price_per_sqm']
        .pct_change() * 100
    ).round(2)
    return df

# 전체 상승률 | 2025(데이터 마지막 년도)평단가 - 2022 년도(데이터 시작년도) 평단가의 차이 %로 계산
def calc_total_change_rate(df):
    df = df.copy()

    total_rate = (
        df
        .groupby(['district_name', 'legal_dong_name'])['avg_price_per_sqm']
        .agg(['first', 'last'])
        .reset_index()
    )

    total_rate['total_change_rate'] = (
        (total_rate['last'] - total_rate['first'])
        / total_rate['first'] * 100
    ).round(2)

    return df.merge(
        total_rate[['district_name', 'legal_dong_name', 'total_change_rate']],
        on=['district_name', 'legal_dong_name'],
        how='left'
    )

# 랭킹 계산
def apply_change_rank(df):
    df = df.copy()
    df['change_rank'] = (
        df
        .groupby('district_name')['total_change_rate']
        .rank(method='dense'     #1, 2, 3 (중복 순위 허용, 다음 순위 건너뛰지 않음)
              , ascending=False) # 상승률 높은 게 1위
        .astype(int)
    )
    return df


district_df = filter_by_district(df_ret, input_district_name)
district_df = calc_price_per_sqm(district_df)

yearly_avg_price = calc_yearly_avg_price(district_df)
yearly_avg_price = format_price_column(yearly_avg_price)
yearly_avg_price = calc_yoy_change_rate(yearly_avg_price)
yearly_avg_price = calc_total_change_rate(yearly_avg_price)
yearly_avg_price = apply_change_rank(yearly_avg_price)

# 랭킹으로 정렬
yearly_avg_price = yearly_avg_price.sort_values(
    by='change_rank',
    ascending=True   # 1위부터
)

yearly_avg_price
# Out:
#     reception_year district_name legal_dong_name  avg_price_per_sqm  \
# 0             2022           강남구             개포동       1.777098e+07
# 1             2023           강남구             개포동       2.541150e+07
# 2             2024           강남구             개포동       2.794019e+07
# 3             2025           강남구             개포동       3.277157e+07
# 8             2022           강남구             대치동       1.775065e+07
# 9             2023           강남구             대치동       2.409501e+07
# 10            2024           강남구             대치동       2.642288e+07
# 11            2025           강남구             대치동       2.889636e+07
# 49            2025           강남구             자곡동       1.356524e+07
# 48            2024           강남구             자곡동       1.400128e+07
# 47            2023           강남구             자곡동       1.271937e+07
# 46            2022           강남구             자곡동       8.608857e+06
# 27            2025           강남구             수서동       2.435616e+07
# 25            2023           강남구             수서동       2.038728e+07
# 24            2022           강남구             수서동       1.604442e+07
# 26            2024           강남구             수서동       2.095607e+07
# 20            2022           강남구             세곡동       1.106011e+07
# 21            2023           강남구             세곡동       1.378686e+07
# 22            2024           강남구             세곡동       1.597014e+07
# 23            2025           강남구             세곡동       1.646413e+07
# 45            2025           강남구             일원동       3.393174e+07
# 43            2023           강남구             일원동       2.337290e+07
# 42            2022           강남구             일원동       2.382253e+07
# 44            2024           강남구             일원동       2.563351e+07
# 41            2024           강남구             율현동       1.780026e+07
# 40            2023           강남구             율현동       1.515456e+07
# 39            2022           강남구             율현동       1.275167e+07
# 16            2022           강남구             삼성동       1.806852e+07
# 17            2023           강남구             삼성동       2.031324e+07
# 18            2024           강남구             삼성동       2.257470e+07
# 19            2025           강남구             삼성동       2.403802e+07
# 14            2024           강남구             도곡동       2.405731e+07
# 13            2023           강남구             도곡동       2.258342e+07
# 15            2025           강남구             도곡동       2.697268e+07
# 12            2022           강남구             도곡동       2.052561e+07
# 28            2022           강남구             신사동       1.752367e+07
# 30            2024           강남구             신사동       2.102667e+07
# 29            2023           강남구             신사동       1.687471e+07
# 37            2024           강남구             역삼동       1.777800e+07
# 38            2025           강남구             역삼동       1.570891e+07
# 35            2022           강남구             역삼동       1.310808e+07
# 36            2023           강남구             역삼동       1.578871e+07
# 7             2025           강남구             논현동       1.678946e+07
# 6             2024           강남구             논현동       1.549079e+07
# 5             2023           강남구             논현동       1.399560e+07
# 4             2022           강남구             논현동       1.438375e+07
# 34            2025           강남구            압구정동       4.282466e+07
# 32            2023           강남구            압구정동       3.474398e+07
# 31            2022           강남구            압구정동       3.772819e+07
# 33            2024           강남구            압구정동       4.062960e+07
# 52            2024           강남구             청담동       2.387967e+07
# 50            2022           강남구             청담동       2.123834e+07
# 51            2023           강남구             청담동       2.633564e+07
# 53            2025           강남구             청담동       2.344284e+07
#
#     transaction_count price_per_sqm_format  yoy_change_rate  \
# 0                 277           17,770,977              NaN
# 1                 639           25,411,503            42.99
# 2                 773           27,940,192             9.95
# 3                  10           32,771,566            17.29
# 8                 274           17,750,651              NaN
# 9                 481           24,095,007            35.74
# 10                580           26,422,883             9.66
# 11                 14           28,896,358             9.36
# 49                  6           13,565,238            -3.11
# 48                244           14,001,277            10.08
# 47                118           12,719,367            47.75
# 46                318            8,608,857              NaN
# 27                  9           24,356,155            16.22
# 25                219           20,387,281            27.07
# 24                 80           16,044,421              NaN
# 26                321           20,956,069             2.79
# 20                 27           11,060,111              NaN
# 21                 73           13,786,860            24.65
# 22                118           15,970,138            15.84
# 23                  2           16,464,133             3.09
# 45                  2           33,931,741            32.37
# 43                272           23,372,902            -1.89
# 42                 71           23,822,534              NaN
# 44                332           25,633,513             9.67
# 41                 14           17,800,259            17.46
# 40                  6           15,154,556            18.84
# 39                  6           12,751,670              NaN
# 16                229           18,068,519              NaN
# 17                246           20,313,237            12.42
# 18                284           22,574,697            11.13
# 19                 12           24,038,022             6.48
# 14                561           24,057,308             6.53
# 13                375           22,583,424            10.03
# 15                 15           26,972,681            12.12
# 12                196           20,525,611              NaN
# 28                218           17,523,674              NaN
# 30                 72           21,026,668            24.60
# 29                 41           16,874,714            -3.70
# 37                838           17,778,005            12.60
# 38                 28           15,708,914           -11.64
# 35               1215           13,108,075              NaN
# 36                717           15,788,712            20.45
# 7                  18           16,789,465             8.38
# 6                 339           15,490,791            10.68
# 5                 210           13,995,601            -2.70
# 4                 423           14,383,750              NaN
# 34                 13           42,824,660             5.40
# 32                124           34,743,984            -7.91
# 31                 40           37,728,192              NaN
# 33                294           40,629,604            16.94
# 52                271           23,879,672            -9.33
# 50                132           21,238,340              NaN
# 51                168           26,335,645            24.00
# 53                  7           23,442,842            -1.83
#
#     total_change_rate  change_rank
# 0               84.41            1
# 1               84.41            1
# 2               84.41            1
# 3               84.41            1
# 8               62.79            2
# 9               62.79            2
# 10              62.79            2
# 11              62.79            2
# 49              57.57            3
# 48              57.57            3
# 47              57.57            3
# 46              57.57            3
# 27              51.80            4
# 25              51.80            4
# 24              51.80            4
# 26              51.80            4
# 20              48.86            5
# 21              48.86            5
# 22              48.86            5
# 23              48.86            5
# 45              42.44            6
# 43              42.44            6
# 42              42.44            6
# 44              42.44            6
# 41              39.59            7
# 40              39.59            7
# 39              39.59            7
# 16              33.04            8
# 17              33.04            8
# 18              33.04            8
# 19              33.04            8
# 14              31.41            9
# 13              31.41            9
# 15              31.41            9
# 12              31.41            9
# 28              19.99           10
# 30              19.99           10
# 29              19.99           10
# 37              19.84           11
# 38              19.84           11
# 35              19.84           11
# 36              19.84           11
# 7               16.73           12
# 6               16.73           12
# 5               16.73           12
# 4               16.73           12
# 34              13.51           13
# 32              13.51           13
# 31              13.51           13
# 33              13.51           13
# 52              10.38           14
# 50              10.38           14
# 51              10.38           14
# 53              10.38           14

# %% [markdown]
# ## 2. 공영주차장 (Public Parkings)

# %%
# SQLAlchemy를 사용하여 데이터 가져오기
parkings = PublicParking.query.limit(5).all()
print(f"가져온 주차장 레코드 수: {len(parkings)}")

# DataFrame으로 변환
stmt = select(PublicParking)
df_pp = pd.read_sql(stmt, db.session.connection())

print(f"총 레코드 수: {len(df_pp)}")
df_pp.head()
# Out:
# 가져온 주차장 레코드 수: 5
# 총 레코드 수: 1875
#    pp_id parking_code     parking_name         address parking_type  \
# 0      1       171721     세종로 공영주차장(시)    종로구 세종로 80-1           NW
# 1      2       171730   종묘주차장 공영주차장(시)     종로구 훈정동 2-0           NW
# 2      3       171900   훈련원공원 공영주차장(시)   중구 을지로5가 40-3           NW
# 3      4       172051    한강진역 공영주차장(시)  용산구 한남동 728-27           NW
# 4      5       172065  용산주차빌딩 공영주차장(시)  용산구 한강로2가 12-9           NW
#
#   parking_type_name operation_type operation_type_name  phone_number  \
# 0            노외 주차장              1             시간제 주차장  02-2290-6566
# 1            노외 주차장              1             시간제 주차장  02-2290-6166
# 2            노외 주차장              1             시간제 주차장  02-3405-4597
# 3            노외 주차장              1             시간제 주차장   02-795-6406
# 4            노외 주차장              1             시간제 주차장  02-2290-6014
#
#   parking_status_available  ... bus_basic_time_min  bus_add_rate  \
# 0                        1  ...                  0             0
# 1                        1  ...                  0             0
# 2                        1  ...                  0             0
# 3                        1  ...                  0             0
# 4                        1  ...                  0             0
#
#    bus_add_time_min day_max_rate        lat         lng  \
# 0                 0        30900  37.573403  126.975884
# 1                 0        28800  37.571504  126.994969
# 2                 0        39600  37.567400  127.003521
# 3                 0        28800  37.539522  127.002580
# 4                 0        21600  37.534364  126.965418
#
#   share_parking_company_name share_parking share_parking_company_link  \
# 0                                        N
# 1                                        N
# 2                                        N
# 3                                        N
# 4                                        N
#
#   share_parking_etc
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 45 columns]
